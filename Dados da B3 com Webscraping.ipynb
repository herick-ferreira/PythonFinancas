# %% [markdown]
# #Configurações Iniciais

# %%
# !pip install -q kora

# %%
from kora.selenium import wd
 
import pandas as pd
from google.colab.data_table import DataTable
from time import sleep

# %% [markdown]
# #Funções e Dados Extraídos

# %%
def busca_carteira_teorica(indice, espera=8):
    url= f'https://sistemaswebb3-listados.b3.com.br/indexPage/day/{indice.upper()}?language=pt-br'
    wd.get(url)
    sleep(espera)
 
    wd.find_element_by_id('segment').send_keys("Setor de Atuação")
    sleep(espera)
 
    wd.find_element_by_link_text('Download').click()
    sleep(espera)
 
    arquivos = !ls -1t *.csv
    return pd.read_csv(arquivos[0], sep=';', encoding='ISO-8859-1', skipfooter=2, engine='python', thousands='.', decimal=',', header=1, index_col=False)

# %%
ibov = busca_carteira_teorica('ibov', 5)

# %%
ibov
# Out:
#                               Setor  Código  ... Part. (%) Part. (%)Acum.
# 0        Bens Indls / Máqs e Equips   WEGE3  ...     2.505          2.505
# 1       Bens Indls / Mat Transporte   EMBR3  ...     0.502          0.502
# 2             Bens Indls/Transporte   AZUL4  ...     0.646          2.726
# 3             Bens Indls/Transporte   CCRO3  ...     0.660          2.726
# 4             Bens Indls/Transporte   ECOR3  ...     0.093          2.726
# ..                              ...     ...  ...       ...            ...
# 77  Utilidade Públ / Energ Elétrica  ENGI11  ...     0.529          5.802
# 78  Utilidade Públ / Energ Elétrica   ENEV3  ...     0.894          5.802
# 79  Utilidade Públ / Energ Elétrica   EGIE3  ...     0.506          5.802
# 80  Utilidade Públ / Energ Elétrica   EQTL3  ...     1.056          5.802
# 81  Utilidade Públ / Energ Elétrica  TAEE11  ...     0.371          5.802
#
# [82 rows x 7 columns]

# %%
ifix = busca_carteira_teorica('ifix', 3)

# %%
DataTable (ifix)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Setor</th>
#       <th>Código</th>
#       <th>Ação</th>
#       <th>Tipo</th>
#       <th>Qtde. Teórica</th>
#       <th>Part. (%)</th>
#       <th>Part. (%)Acum.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>ABCP11</td>
#       <td>FII ABC IMOB</td>
#       <td>CI</td>
#       <td>12203833</td>
#       <td>1.068</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>BPFF11</td>
#       <td>FII ABSOLUTO</td>
#       <td>CI</td>
#       <td>4492326</td>
#       <td>0.387</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>ALZR11</td>
#       <td>FII ALIANZA</td>
#       <td>CI  ER</td>
#       <td>4479484</td>
#       <td>0.605</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>BARI11</td>
#       <td>FII BARIGUI</td>
#       <td>CI</td>
#       <td>4234190</td>
#       <td>0.534</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>BBPO11</td>
#       <td>FII BB PRGII</td>
#       <td>CI</td>
#       <td>15919690</td>
#       <td>2.006</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>XPLG11</td>
#       <td>FII XP LOG</td>
#       <td>CI</td>
#       <td>26043793</td>
#       <td>3.261</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>XPCM11</td>
#       <td>FII XP MACAE</td>
#       <td>CI</td>
#       <td>2414570</td>
#       <td>0.108</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>XPML11</td>
#       <td>FII XP MALLS</td>
#       <td>CI  ER</td>
#       <td>18207683</td>
#       <td>2.101</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>XPPR11</td>
#       <td>FII XP PROP</td>
#       <td>CI</td>
#       <td>7316171</td>
#       <td>0.586</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>Financ e Outros / Fundos</td>
#       <td>XPSF11</td>
#       <td>FII XP SELEC</td>
#       <td>CI</td>
#       <td>4330214</td>
#       <td>0.464</td>
#       <td>100.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>87 rows × 7 columns</p>
# </div>
