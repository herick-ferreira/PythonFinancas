# %% [markdown]
# Para instalar o YFinance (Yahoo Finance)

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#      |████████████████████████████████| 5.5MB 6.7MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=f119c39390b04508063215f2dfe3f49199988014972e6738b126e831661275f1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-972095dg/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %% [markdown]
# Para importar as bibliotecas necessárias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %% [markdown]
# Para importar o YFinance e sobrescrevendo os métodos do pandas_datareader

# %%
import yfinance as yf
yf.pdr_override()

# %% [markdown]
# Buscando os dados no mercado

# %% [markdown]
# Baixando as cotações no Yahoo Finance para o Índice Bovespa

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
#  Exibindo as primeiras cotações mais antigas

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %% [markdown]
#  Exibindo as cotações atuais

# %%
ibov.tail()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2021-02-08  120239.0  120844.0  119140.0  119516.0   119516.0  8619100
# 2021-02-09  119696.0  119975.0  118246.0  119429.0   119429.0  7913500
# 2021-02-10  119472.0  119738.0  117970.0  118430.0   118430.0  8644600
# 2021-02-11  118440.0  120283.0  118440.0  119235.0   119235.0  7567400
# 2021-02-12  119300.0  119763.0  118163.0  119116.0   119116.0  7655900

# %% [markdown]
# Mostrando um gráfico com o fechamento do índice

# %%
ibov["Close"].plot(figsize=(22,8))
