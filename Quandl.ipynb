# %% [markdown]
# Configurações Iniciais

# %%
# !pip install -q quandl

# %%
import pandas as pd
import quandl

# %% [markdown]
# Configurando Chave de Acesso

# %%
quandl.ApiConfig.api_key = 'CHAVE DE ACESSO'

# %% [markdown]
# Obtendo Dados

# %%
ipca = quandl.get('BCB/433')
ipca

# %%
acucar = quandl.get('CEPEA/SUGAR_C')
acucar

# %%
big_mac = quandl.get('ECONOMIST/BIGMAC_BRA')
big_mac

# %%
price_btc = quandl.get('BCMAIN/MCPRU')
price_btc

# %%
price_btc.plot()
